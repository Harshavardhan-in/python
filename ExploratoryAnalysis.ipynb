# %%
#Data Manipulation
import pandas as pd
import numpy as np

#Data Viz
#pip install autoviz
#pip install sklearn
#pip install seaborn
#pip install matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# apply some cool styling
plt.style.use("ggplot")
rcParams['figure.figsize'] = (12,  6)

# %%
import pandas as pd
import os
os.chdir('/Users/harshavardhanalavala/Downloads')

# %%
df=pd.read_csv('avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
rs = np.random.RandomState(0)
df1 = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_705a8_row0_col0, #T_705a8_row1_col1, #T_705a8_row2_col2, #T_705a8_row3_col3, #T_705a8_row4_col4, #T_705a8_row5_col5, #T_705a8_row6_col6, #T_705a8_row7_col7, #T_705a8_row8_col8, #T_705a8_row9_col9, #T_705a8_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col2, #T_705a8_row10_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col6, #T_705a8_row0_col7, #T_705a8_row3_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col8, #T_705a8_row4_col10, #T_705a8_row8_col0, #T_705a8_row10_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_705a8_row0_col9 {
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
print(df['Total Bags'].describe())
plt.figure(figsize=(19, 18))
sns.distplot(df['Total Bags'], color='g', bins=500, hist_kws={'alpha': 0.5});
# Out:
# count    1.824900e+04
# mean     2.396392e+05
# std      9.862424e+05
# min      0.000000e+00
# 25%      5.088640e+03
# 50%      3.974383e+04
# 75%      1.107834e+05
# max      1.937313e+07
# Name: Total Bags, dtype: float64
# /var/folders/sf/v5zb3xr90js87h255t7zngnw0000gn/T/ipykernel_44643/1087666748.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Bags'], color='g', bins=500, hist_kws={'alpha': 0.5});

# %%
df.hist(figsize=(6, 10), bins=50, xlabelsize=8, ylabelsize=8);

# %%
sns.catplot(x="type", y="year", data=df, kind="box", aspect=1.5)
plt.title("Boxplot for type vs year")
plt.show()

# %%
sns.scatterplot(x="year", y="Total Volume", hue="type", data=df, palette="Dark2", s=70)
plt.title("Relationship between AGE, DEMAND_QTY AND GENDER")
plt.show()

# %% [markdown]
# * This is a statistical method of choosing features using the Spearman method. This method assesses how well the relationship between 2 features can be described usiung a montonic function

# %%
correlation_matrix = df.corr(method='spearman')
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
f, ax = plt.subplots(figsize=(12, 12))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(correlation_matrix, mask=mask, cmap=cmap, vmax=.5, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >
